# %% [markdown]
# ## Tetraquarks & Pentaquarks

# %% [markdown]
# * Tetraquarks $\sim$ Di-Mesons: Bound states made of two meson-type HC singlets. Can be molecule-like or compact (requires two heavy flavors in QCD)
#
# * Baryons: Genuine bound states of only fundamentals contracted by $\epsilon$ tensor in SU(N), SO(N). (Note, that $\epsilon$ tensor does not exist for Sp(N))
#
# * Other type of bound states:
#     - single flavor symmetry, e.g. M7: $16 \otimes 16 \otimes 16 \otimes 16 = (10 \oplus 120 \oplus 126)^2 \supset 1$ of SO(10)
#     - mixed flavor symmetry, e.g. M12: $\bar \psi \chi \chi \chi \supset 1$

# %%
from itertools import combinations_with_replacement
from groups.groups import Simple, SO, SU, Sp, U1
from groups.irreps import Irrep, get_rep, tensor_product, SumIrrep

# %%
def hc_singlets(psi: Irrep, chi: Irrep, Nfermions: int, symmetries: tuple[Simple, ...], psibar=None, chibar=None):
    HC, Gc, Hc, Gew, Hew = symmetries

    if psibar:
        psis = (psi, psibar)
        str_psis = ('psi', 'psibar')
    else:
        psis = (psi, )
        str_psis = ('psi', )
    if chibar:
        chis = (chi, chibar)
        str_chis = ('chi', 'chibar')
    else:
        chis = (chi, )
        str_chis = ('chi', )

    combs = combinations_with_replacement((*psis, *chis), Nfermions)
    str_combs = combinations_with_replacement((*str_psis, *str_chis), Nfermions)

    for str_comb, comb in zip(str_combs, combs):
        try:
            all_irreps = tensor_product(*comb)
        except Exception as e:
            print(f'Could not calculate {str_comb}: {e}')
            continue

        boundstates = get_rep(all_irreps, HC.irrep(1))
        if boundstates:
            global_symmetries = SumIrrep(list(set(boundstates.summands)))
            print(*str_comb, ': ', global_symmetries)
            '''if Hc != SU(3):
                su3reps = global_symmetries.remove(HC).decompose(Hc, decompose_from=Gc).decompose(SU(3)*U1(), decompose_from=Hc)
            else:
                su3reps = global_symmetries.remove(HC).decompose(Hc, decompose_from=Gc)
            su3reps = SumIrrep(list(set(su3reps.summands)))
            print(f'       -> {su3reps}')

            smreps = su3reps.decompose(Hew, decompose_from=Gew).decompose(SU(2, 'L') * SU(2, 'R'), decompose_from=Hew)
            print(f'       -> {SumIrrep(list(set(smreps.summands)))}')'''
            print()


def tetra_and_penta(psi, chi, Sgroups, psibar=None, chibar=None):
    print('Tetraquarks:')
    hc_singlets(psi, chi, 4, Sgroups, psibar=psibar, chibar=chibar)
    print()
    print('Pentaquarks:')
    hc_singlets(psi, chi, 5, Sgroups, psibar=psibar, chibar=chibar)

# %% [markdown]
# ## M1

# %%
HC = SO(7)
Gc = SU(6)
Gew = SU(5)
Sgroups = (HC, Gc, SO(6), Gew, SO(5))

psi = HC.irrep(7) * Gew.irrep(5) * Gc.irrep(1)
chi = HC.irrep(8) * Gew.irrep(1) * Gc.irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 105bar, 1) + (1, 70'bar, 1) + (1, 50bar, 1) + (1, 45bar, 1) + (1, 5bar, 1) of SU6 x SU5 x SO7
#
# psi psi chi chi :  (21, 15, 1) + (21, 10, 1) + (15, 15, 1) + (15, 10, 1) of SU6 x SU5 x SO7
#
# chi chi chi chi :  (210'bar, 1, 1) + (126bar, 1, 1) + (105bar, 1, 1) + (105'bar, 1, 1) + (15bar, 1, 1) of SU6 x SU5 x SO7
#
#
# Pentaquarks:
# psi psi psi chi chi :  (21, 40bar, 1) + (21, 35bar, 1) + (21, 10bar, 1) + (15, 40bar, 1) + (15, 35bar, 1) + (15, 10bar, 1) of SU6 x SU5 x SO7
#
# psi chi chi chi chi :  (210'bar, 5, 1) + (126bar, 5, 1) + (105bar, 5, 1) + (105'bar, 5, 1) + (15bar, 5, 1) of SU6 x SU5 x SO7

# %% [markdown]
# ## M2

# %%
HC = SO(9)
Gc = SU(6)
Gew = SU(5)
Sgroups = (HC, Gc, SO(6), Gew, SO(5))

psi = HC.irrep(9) * Gew.irrep(5) * Gc.irrep(1)
chi = HC.irrep(16) * Gew.irrep(1) * Gc.irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 1, 105bar) + (1, 1, 70'bar) + (1, 1, 50bar) + (1, 1, 45bar) + (1, 1, 5bar) of SU6 x SO9 x SU5
#
# psi psi chi chi :  (21, 1, 15) + (21, 1, 10) + (15, 1, 15) + (15, 1, 10) of SU6 x SO9 x SU5
#
# chi chi chi chi :  (210'bar, 1, 1) + (126bar, 1, 1) + (105bar, 1, 1) + (105'bar, 1, 1) + (15bar, 1, 1) of SU6 x SO9 x SU5
#
#
# Pentaquarks:
# psi psi psi chi chi :  (21, 1, 40bar) + (21, 1, 35bar) + (21, 1, 10bar) + (15, 1, 40bar) + (15, 1, 35bar) + (15, 1, 10bar) of SU6 x SO9 x SU5
#
# psi chi chi chi chi :  (210'bar, 1, 5) + (126bar, 1, 5) + (105bar, 1, 5) + (105'bar, 1, 5) + (15bar, 1, 5) of SU6 x SO9 x SU5

# %% [markdown]
# ## M3

# %%
HC = SO(7)
Gc = SU(6)
Gew = SU(5)
Sgroups = (HC, Gc, SO(6), Gew, SO(5))

psi = HC.irrep(8) * SU(5).irrep(5) * SU(6).irrep(1)
chi = HC.irrep(7) * SU(5).irrep(1) * SU(6).irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 105bar, 1) + (1, 70'bar, 1) + (1, 50bar, 1) + (1, 45bar, 1) + (1, 5bar, 1) of SU6 x SU5 x SO7
#
# psi psi chi chi :  (21, 15, 1) + (21, 10, 1) + (15, 15, 1) + (15, 10, 1) of SU6 x SU5 x SO7
#
# chi chi chi chi :  (210'bar, 1, 1) + (126bar, 1, 1) + (105bar, 1, 1) + (105'bar, 1, 1) + (15bar, 1, 1) of SU6 x SU5 x SO7
#
#
# Pentaquarks:
# psi psi psi psi chi :  (6, 105bar, 1) + (6, 70'bar, 1) + (6, 50bar, 1) + (6, 45bar, 1) + (6, 5bar, 1) of SU6 x SU5 x SO7
#
# psi psi chi chi chi :  (70, 15, 1) + (70, 10, 1) + (56, 15, 1) + (56, 10, 1) + (20, 15, 1) + (20, 10, 1) of SU6 x SU5 x SO7

# %% [markdown]
# ## M4

# %%
HC = SO(9)
Gc = SU(6)
Gew = SU(5)
Sgroups = (HC, Gc, SO(6), Gew, SO(5))

psi = HC.irrep(16) * SU(5).irrep(5) * SU(6).irrep(1)
chi = HC.irrep(9) * SU(5).irrep(1) * SU(6).irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 1, 105bar) + (1, 1, 70'bar) + (1, 1, 50bar) + (1, 1, 45bar) + (1, 1, 5bar) of SU6 x SO9 x SU5
#
# psi psi chi chi :  (21, 1, 15) + (21, 1, 10) + (15, 1, 15) + (15, 1, 10) of SU6 x SO9 x SU5
#
# chi chi chi chi :  (210'bar, 1, 1) + (126bar, 1, 1) + (105bar, 1, 1) + (105'bar, 1, 1) + (15bar, 1, 1) of SU6 x SO9 x SU5
#
#
# Pentaquarks:
# psi psi psi psi chi :  (6, 1, 105bar) + (6, 1, 70'bar) + (6, 1, 50bar) + (6, 1, 45bar) + (6, 1, 5bar) of SU6 x SO9 x SU5
#
# psi psi chi chi chi :  (70, 1, 15) + (70, 1, 10) + (56, 1, 15) + (56, 1, 10) + (20, 1, 15) + (20, 1, 10) of SU6 x SO9 x SU5

# %% [markdown]
# ## M5

# %%
HC = Sp(4)
Gc = SU(6)
Gew = SU(5)
Sgroups = (HC, Gc, Sp(6), Gew, SO(5))

psi = HC.antisymmetric() * SU(5).irrep(5) * SU(6).irrep(1)
chi = HC.irrep(4) * SU(5).irrep(1) * SU(6).irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 105bar, 1) + (1, 70'bar, 1) + (1, 50bar, 1) + (1, 45bar, 1) + (1, 5bar, 1) of SU6 x SU5 x Sp4
#
# psi psi chi chi :  (21, 15, 1) + (21, 10, 1) + (15, 15, 1) + (15, 10, 1) of SU6 x SU5 x Sp4
#
# chi chi chi chi :  (210'bar, 1, 1) + (126bar, 1, 1) + (105bar, 1, 1) + (105'bar, 1, 1) + (15bar, 1, 1) of SU6 x SU5 x Sp4
#
#
# Pentaquarks:
# psi psi psi psi psi :  (1, 224, 1) + (1, 175', 1) + (1, 126, 1) + (1, 126', 1) + (1, 75, 1) + (1, 24, 1) + (1, 1, 1) of SU6 x SU5 x Sp4
#
# psi psi psi chi chi :  (21, 40bar, 1) + (21, 35bar, 1) + (21, 10bar, 1) + (15, 40bar, 1) + (15, 35bar, 1) + (15, 10bar, 1) of SU6 x SU5 x Sp4
#
# psi chi chi chi chi :  (210'bar, 5, 1) + (126bar, 5, 1) + (105bar, 5, 1) + (105'bar, 5, 1) + (15bar, 5, 1) of SU6 x SU5 x Sp4

# %% [markdown]
# ## M6

# %%
HC = SU(4)
Gc = SU(3, '0') * SU(3, '1')
Gew = SU(5)
Sgroups = (HC, Gc, SU(3), Gew, SO(5))

psi = HC.antisymmetric() * Gew.irrep(5) * Gc.irrep([1,1]) * U1().irrep(0)
chi = HC.irrep(4) * Gew.irrep(1) * Gc.irrep([3,1]) * U1().irrep(1)
chibar = HC.irrep(-4) * Gew.irrep(1) * Gc.irrep([1,-3]) * U1().irrep(-1)

tetra_and_penta(psi, chi, Sgroups, chibar=chibar)
# Out:
# Tetraquarks:
# psi psi psi psi :  (105bar, 1, 1, 1; 0) + (70'bar, 1, 1, 1; 0) + (50bar, 1, 1, 1; 0) + (45bar, 1, 1, 1; 0) + (5bar, 1, 1, 1; 0) of SU5 x SU4 x SU3_0 x SU3_1 x U1
#
# psi psi chi chibar :  (15, 1, 3, 3bar; 0) + (10, 1, 3, 3bar; 0) of SU5 x SU4 x SU3_0 x SU3_1 x U1
#
# chi chi chi chi :  (1, 1, 15, 1; 4) + (1, 1, 15', 1; 4) + (1, 1, 6bar, 1; 4) + (1, 1, 3, 1; 4) of SU5 x SU4 x SU3_0 x SU3_1 x U1
#
# chi chi chibar chibar :  (1, 1, 6, 6bar; 0) + (1, 1, 6, 3; 0) + (1, 1, 3bar, 6bar; 0) + (1, 1, 3bar, 3; 0) of SU5 x SU4 x SU3_0 x SU3_1 x U1
#
# chibar chibar chibar chibar :  (1, 1, 1, 15bar; -4) + (1, 1, 1, 15'bar; -4) + (1, 1, 1, 6; -4) + (1, 1, 1, 3bar; -4) of SU5 x SU4 x SU3_0 x SU3_1 x U1
#
#
# Pentaquarks:
# psi psi psi chi chi :  (40bar, 1, 6, 1; 2) + (40bar, 1, 3bar, 1; 2) + (35bar, 1, 6, 1; 2) + (35bar, 1, 3bar, 1; 2) + (10bar, 1, 6, 1; 2) + (10bar, 1, 3bar, 1; 2) of SU5 x SU4 x SU3_0 x SU3_1 x U1
#
# ...

# %% [markdown]
# ## M7

# %%
HC = SO(10)
Gc = SU(3, '0') * SU(3, '1')
Gew = SU(5)
Sgroups = (HC, Gc, SU(3), Gew, SO(5))

psi = HC.irrep(10) * SU(5).irrep(5) * SU(3, '0').irrep(1) * SU(3, '1').irrep(1) * U1().irrep(0)
chi = HC.irrep(16) * SU(5).irrep(1) * SU(3, '0').irrep(3) * SU(3, '1').irrep(1) * U1().irrep(1)
chibar = HC.irrep(-16) * SU(5).irrep(1) * SU(3, '0').irrep(1) * SU(3, '1').irrep(-3) * U1().irrep(-1)

tetra_and_penta(psi, chi, Sgroups, chibar=chibar)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 105bar, 1, 1; 0) + (1, 70'bar, 1, 1; 0) + (1, 50bar, 1, 1; 0) + (1, 45bar, 1, 1; 0) + (1, 5bar, 1, 1; 0) of SO10 x SU5 x SU3_0 x SU3_1 x U1
#
# psi psi chi chibar :  (1, 15, 3, 3bar; 0) + (1, 10, 3, 3bar; 0) of SO10 x SU5 x SU3_0 x SU3_1 x U1
#
# chi chi chi chi :  (1, 1, 15, 1; 4) + (1, 1, 15', 1; 4) + (1, 1, 6bar, 1; 4) + (1, 1, 3, 1; 4) of SO10 x SU5 x SU3_0 x SU3_1 x U1
#
# chi chi chibar chibar :  (1, 1, 6, 6bar; 0) + (1, 1, 6, 3; 0) + (1, 1, 3bar, 6bar; 0) + (1, 1, 3bar, 3; 0) of SO10 x SU5 x SU3_0 x SU3_1 x U1
#
# chibar chibar chibar chibar :  (1, 1, 1, 15bar; -4) + (1, 1, 1, 15'bar; -4) + (1, 1, 1, 6; -4) + (1, 1, 1, 3bar; -4) of SO10 x SU5 x SU3_0 x SU3_1 x U1
#
#
# Pentaquarks:
# psi psi psi chi chi :  (1, 40bar, 6, 1; 2) + (1, 40bar, 3bar, 1; 2) + (1, 35bar, 6, 1; 2) + (1, 35bar, 3bar, 1; 2) + (1, 10bar, 6, 1; 2) + (1, 10bar, 3bar, 1; 2) of SO10 x SU5 x SU3_0 x SU3_1 x U1
#
# ...

# %% [markdown]
# ## M8

# %%
HC = Sp(4)
Gc = SU(6)
Gew = SU(4)
Sgroups = (HC, Gc, SO(6), Gew, Sp(4))

psi = HC.irrep(4) * SU(4).irrep(4) * SU(6).irrep(1)
chi = HC.antisymmetric() * SU(4).irrep(1) * SU(6).irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 45, 1) + (1, 35, 1) + (1, 20', 1) + (1, 15, 1) + (1, 1, 1) of SU6 x SU4 x Sp4
#
# psi psi chi chi :  (21, 10, 1) + (21, 6, 1) + (15, 10, 1) + (15, 6, 1) of SU6 x SU4 x Sp4
#
# chi chi chi chi :  (210'bar, 1, 1) + (126bar, 1, 1) + (105bar, 1, 1) + (105'bar, 1, 1) + (15bar, 1, 1) of SU6 x SU4 x Sp4
#
#
# Pentaquarks:
# psi psi psi psi chi :  (6, 45, 1) + (6, 35, 1) + (6, 20', 1) + (6, 15, 1) + (6, 1, 1) of SU6 x SU4 x Sp4
#
# psi psi chi chi chi :  (70, 10, 1) + (70, 6, 1) + (56, 10, 1) + (56, 6, 1) + (20, 10, 1) + (20, 6, 1) of SU6 x SU4 x Sp4
#
# chi chi chi chi chi :  (504bar, 1, 1) + (420bar, 1, 1) + (336bar, 1, 1) + (252bar, 1, 1) + (210bar, 1, 1) + (84bar, 1, 1) + (6bar, 1, 1) of SU6 x SU4 x Sp4

# %% [markdown]
# ## M9

# %%
HC = SO(11)
Gc = SU(6)
Gew = SU(4)
Sgroups = (HC, Gc, SO(6), Gew, Sp(4))

psi = HC.irrep(32) * SU(4).irrep(4) * SU(6).irrep(1)
chi = HC.irrep(11) * SU(4).irrep(1) * SU(6).irrep(6)

tetra_and_penta(psi, chi, Sgroups)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 1, 45) + (1, 1, 35) + (1, 1, 20') + (1, 1, 15) + (1, 1, 1) of SO11 x SU6 x SU4
#
# psi psi chi chi :  (1, 21, 10) + (1, 21, 6) + (1, 15, 10) + (1, 15, 6) of SO11 x SU6 x SU4
#
# chi chi chi chi :  (1, 210'bar, 1) + (1, 126bar, 1) + (1, 105bar, 1) + (1, 105'bar, 1) + (1, 15bar, 1) of SO11 x SU6 x SU4
#
#
# Pentaquarks:
# psi psi psi psi chi :  (1, 6, 45) + (1, 6, 35) + (1, 6, 20') + (1, 6, 15) + (1, 6, 1) of SO11 x SU6 x SU4
#
# psi psi chi chi chi :  (1, 70, 10) + (1, 70, 6) + (1, 56, 10) + (1, 56, 6) + (1, 20, 10) + (1, 20, 6) of SO11 x SU6 x SU4

# %% [markdown]
# ## M10

# %%
HC = SO(10)
Gc = SU(6)
Gew = SU(4, '0') * SU(4, '1')
Sgroups = (HC, Gc, SO(6), Gew, SU(4))

psi = HC.irrep(16) * Gew.irrep([4,1]) * SU(6).irrep(1) * U1('ew').irrep(1)
psibar = HC.irrep(-16) * Gew.irrep([1,-4]) * SU(6).irrep(1) * U1('ew').irrep(-1)
chi = HC.irrep(10) * Gew.irrep([1,1]) * SU(6).irrep(6) * U1('ew').irrep(0)

tetra_and_penta(psi, chi, Sgroups, psibar=psibar)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 1, 45, 1; 4) + (1, 1, 35, 1; 4) + (1, 1, 20', 1; 4) + (1, 1, 15, 1; 4) + (1, 1, 1, 1; 4) of SO10 x SU6 x SU4_0 x SU4_1 x U1_ew
#
# psi psi psibar psibar :  (1, 1, 10, 10bar; 0) + (1, 1, 10, 6; 0) + (1, 1, 6, 10bar; 0) + (1, 1, 6, 6; 0) of SO10 x SU6 x SU4_0 x SU4_1 x U1_ew
#
# psi psibar chi chi :  (1, 21, 4, 4bar; 0) + (1, 15, 4, 4bar; 0) of SO10 x SU6 x SU4_0 x SU4_1 x U1_ew
#
# psibar psibar psibar psibar :  (1, 1, 1, 45bar; -4) + (1, 1, 1, 35bar; -4) + (1, 1, 1, 20'; -4) + (1, 1, 1, 15; -4) + (1, 1, 1, 1; -4) of SO10 x SU6 x SU4_0 x SU4_1 x U1_ew
#
# chi chi chi chi :  (1, 210'bar, 1, 1; 0) + (1, 126bar, 1, 1; 0) + (1, 105bar, 1, 1; 0) + (1, 105'bar, 1, 1; 0) + (1, 15bar, 1, 1; 0) of SO10 x SU6 x SU4_0 x SU4_1 x U1_ew
#
#
# Pentaquarks:
# psi psi psi psibar chi :  (1, 6, 20bar, 4bar; 2) + (1, 6, 20''bar, 4bar; 2) + (1, 6, 4bar, 4bar; 2) of SO10 x SU6 x SU4_0 x SU4_1 x U1_ew
#
# ...

# %% [markdown]
# ## M11

# %%
HC = SU(4)
Gc = SU(6)
Gew = SU(4, '0') * SU(4, '1')
Sgroups = (HC, Gc, SO(6), Gew, SU(4))

psi = HC.irrep(4) * SU(4, '0').irrep(4) * SU(4, '1').irrep(1) * SU(6).irrep(1) * U1('ew').irrep(1)
psibar = HC.irrep(-4) * SU(4, '0').irrep(1) * SU(4, '1').irrep(-4) * SU(6).irrep(1) * U1('ew').irrep(0)
chi = HC.antisymmetric() * SU(4, '0').irrep(1) * SU(4, '1').irrep(1) * SU(6).irrep(6) * U1('ew').irrep(0)

tetra_and_penta(psi, chi, Sgroups, psibar=psibar)
# Out:
# Tetraquarks:
# psi psi psi psi :  (1, 1, 45, 1; 4) + (1, 1, 35, 1; 4) + (1, 1, 20', 1; 4) + (1, 1, 15, 1; 4) + (1, 1, 1, 1; 4) of SU6 x SU4 x SU4_0 x SU4_1 x U1_ew
#
# psi psi psibar psibar :  (1, 1, 10, 10bar; 2) + (1, 1, 10, 6; 2) + (1, 1, 6, 10bar; 2) + (1, 1, 6, 6; 2) of SU6 x SU4 x SU4_0 x SU4_1 x U1_ew
#
# psi psibar chi chi :  (21, 1, 4, 4bar; 1) + (15, 1, 4, 4bar; 1) of SU6 x SU4 x SU4_0 x SU4_1 x U1_ew
#
# psibar psibar psibar psibar :  (1, 1, 1, 45bar; 0) + (1, 1, 1, 35bar; 0) + (1, 1, 1, 20'; 0) + (1, 1, 1, 15; 0) + (1, 1, 1, 1; 0) of SU6 x SU4 x SU4_0 x SU4_1 x U1_ew
#
# chi chi chi chi :  (210'bar, 1, 1, 1; 0) + (126bar, 1, 1, 1; 0) + (105bar, 1, 1, 1; 0) + (105'bar, 1, 1, 1; 0) + (15bar, 1, 1, 1; 0) of SU6 x SU4 x SU4_0 x SU4_1 x U1_ew
#
#
# Pentaquarks:
# psi psi psi psibar chi :  (6, 1, 20bar, 4bar; 3) + (6, 1, 20''bar, 4bar; 3) + (6, 1, 4bar, 4bar; 3) of SU6 x SU4 x SU4_0 x SU4_1 x U1_ew
#
# ...

# %% [markdown]
# # M12

# %%
HC = SU(5)
Gc = SU(3, '0') * SU(3, '1')
Gew = SU(4, '0') * SU(4, '1')
Sgroups = (HC, Gc, SU(3), Gew, SU(4))

psi = HC.irrep(5) * SU(4, '0').irrep(4) * SU(4, '1').irrep(1) * SU(3, '0').irrep(1) * SU(3, '1').irrep(1) * U1('ew').irrep(1) * U1('x').irrep(0)
psibar = HC.irrep(-5) * SU(4, '0').irrep(1) * SU(4, '1').irrep(-4) * SU(3, '0').irrep(1) * SU(3, '1').irrep(1) * U1('ew').irrep(-1) * U1('x').irrep(0)
chi = HC.irrep(10) * SU(4, '0').irrep(1) * SU(4, '1').irrep(1) * SU(3, '0').irrep(3) * SU(3, '1').irrep(1) * U1('ew').irrep(0) * U1('x').irrep(1)
chibar = HC.irrep(-10) * SU(4, '0').irrep(1) * SU(4, '1').irrep(1) * SU(3, '0').irrep(1) * SU(3, '1').irrep(-3) * U1('ew').irrep(0) * U1('x').irrep(-1)

tetra_and_penta(psi, chi, Sgroups, psibar=psibar, chibar=chibar)
# Out:
# Tetraquarks:
# psi psi psi chi :  (1, 20bar, 1, 3, 1; 3; 1) + (1, 20''bar, 1, 3, 1; 3; 1) + (1, 4bar, 1, 3, 1; 3; 1) of SU5 x SU4_0 x SU4_1 x SU3_0 x SU3_1 x U1_ew x U1_x
#
# psi psi psibar psibar :  (1, 10, 10bar, 1, 1; 0; 0) + (1, 10, 6, 1, 1; 0; 0) + (1, 6, 10bar, 1, 1; 0; 0) + (1, 6, 6, 1, 1; 0; 0) of SU5 x SU4_0 x SU4_1 x SU3_0 x SU3_1 x U1_ew x U1_x
#
# psi psibar chi chibar :  (1, 4, 4bar, 3, 3bar; 0; 0) of SU5 x SU4_0 x SU4_1 x SU3_0 x SU3_1 x U1_ew x U1_x
#
# psi chibar chibar chibar :  (1, 4, 1, 1, 10bar; 1; -3) + (1, 4, 1, 1, 8; 1; -3) + (1, 4, 1, 1, 1; 1; -3) of SU5 x SU4_0 x SU4_1 x SU3_0 x SU3_1 x U1_ew x U1_x
#
# psibar psibar psibar chibar :  (1, 1, 20, 1, 3bar; -3; -1) + (1, 1, 20'', 1, 3bar; -3; -1) + (1, 1, 4, 1, 3bar; -3; -1) of SU5 x SU4_0 x SU4_1 x SU3_0 x SU3_1 x U1_ew x U1_x
#
# psibar chi chi chi :  (1, 1, 4bar, 10, 1; -1; 3) + (1, 1, 4bar, 8, 1; -1; 3) + (1, 1, 4bar, 1, 1; -1; 3) of SU5 x SU4_0 x SU4_1 x SU3_0 x SU3_1 x U1_ew x U1_x
#
# ...
